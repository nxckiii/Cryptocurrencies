# %%
import pandas as pd

# %%
file_path = "C:/Users/nisha/Cryptocurrencies/csv/iris.csv"
iris_df = pd.read_csv(file_path)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
new_iris_df = iris_df.drop(['class'], axis=1)
new_iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
output_file_path = "C:/Users/nisha/Cryptocurrencies/csv/new_iris_data.csv"
new_iris_df.to_csv(output_file_path, index=False)

# %%
# Data loading
shopfile_path = "C:/Users/nisha/Cryptocurrencies/csv/shopping_data.csv"
df_shopping = pd.read_csv(shopfile_path, encoding="ISO-8859-1")
df_shopping.head()
# Out:
#    CustomerID Card Member   Age  Annual Income  Spending Score (1-100)
# 0           1         Yes  19.0          15000                    39.0
# 1           2         Yes  21.0          15000                    81.0
# 2           3          No  20.0          16000                     6.0
# 3           4          No  23.0          16000                    77.0
# 4           5          No  31.0          17000                    40.0

# %%
# Columns
df_shopping.columns
# Out:
# Index(['CustomerID', 'Card Member', 'Age', 'Annual Income',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# List dataframe data types
df_shopping.dtypes
# Out:
# CustomerID                  int64
# Card Member                object
# Age                       float64
# Annual Income               int64
# Spending Score (1-100)    float64
# dtype: object

# %%
# Find null values
for column in df_shopping.columns: 
    print(f"Column {column} has {df_shopping[column].isnull().sum()} null values")
# Out:
# Column CustomerID has 0 null values
# Column Card Member has 2 null values
# Column Age has 2 null values
# Column Annual Income has 0 null values
# Column Spending Score (1-100) has 1 null values

# %%
# Drop null rows
df_shopping = df_shopping.dropna()

# %%
# Find duplicate entries
print(f"Duplicate entries:{df_shopping.duplicated().sum()}")
# Out:
# Duplicate entries:0

# %%
# Remove the CustomerID Column
df_shopping.drop(columns=['CustomerID'], inplace=True)
df_shopping.head()
# Out:
#   Card Member   Age  Annual Income  Spending Score (1-100)
# 0         Yes  19.0          15000                    39.0
# 1         Yes  21.0          15000                    81.0
# 2          No  20.0          16000                     6.0
# 3          No  23.0          16000                    77.0
# 4          No  31.0          17000                    40.0

# %%
# Transform String column 
def change_string(member):
    if member == "Yes":
        return 1
    else:
        return 0
    
df_shopping["Card Member"] = df_shopping["Card Member"].apply(change_string) 
df_shopping.head()
# Out:
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0          15000                    39.0
# 1            1  21.0          15000                    81.0
# 2            0  20.0          16000                     6.0
# 3            0  23.0          16000                    77.0
# 4            0  31.0          17000                    40.0

# %%
# Transform annual income
df_shopping["Annual Income"] = df_shopping["Annual Income"] / 1000
df_shopping.head()
# Out:
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0           15.0                    39.0
# 1            1  21.0           15.0                    81.0
# 2            0  20.0           16.0                     6.0
# 3            0  23.0           16.0                    77.0
# 4            0  31.0           17.0                    40.0

# %%
# Saving cleaned data
file_path = "C:/Users/nisha/Cryptocurrencies/csv/shopping_data_cleaned.csv"
df_shopping.to_csv(file_path, index=False)

# %%
# !pip install holoviews==1.13.3
# Out:
# ...
#   Attempting uninstall: holoviews
#     Found existing installation: holoviews 1.14.9
#     Uninstalling holoviews-1.14.9:
#       Successfully uninstalled holoviews-1.14.9
# ...

# %%
import pandas as pd
import plotly.express as px
import hvplot.pandas 
from sklearn.cluster import KMeans
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4800/1797589095.py in <module>
#       1 import pandas as pd
#       2 import plotly.express as px
# ----> 3 import hvplot.pandas
#       4 from sklearn.cluster import KMeans
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\__init__.py in <module>
#     128     for _kind in HoloViewsConverter._kind_mapping:
#     129         if hasattr(cls, _kind):
# --> 130             _patch_doc(cls, _kind)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\hvplot\__init__.py in _patch_doc(cls, kind)
#     119         method.__func__.__doc__ = docstring
#     120     else:
# --> 121         docstring, signature = _get_doc_and_signature(cls, kind, False)
#     122         method.__doc__ = docstring
#     123         method.__signature__ = signature
#
# ...

# %%
# !pip freeze
# Out:
# alabaster==0.7.12
# anaconda-client @ file:///C:/ci/anaconda-client_1635342757050/work
# anaconda-project @ file:///tmp/build/80754af9/anaconda-project_1626085644852/work
# anyio @ file:///C:/ci/anyio_1620153167783/work/dist
# appdirs==1.4.4
# argcomplete @ file:///tmp/build/80754af9/argcomplete_1618920853202/work
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1613038019788/work
# arrow==0.13.1
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1628063231892/work
# astropy @ file:///C:/ci/astropy_1629829319964/work
# async-generator==1.10
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1620827162558/work
# autopep8 @ file:///tmp/build/80754af9/autopep8_1620866417880/work
# Babel @ file:///tmp/build/80754af9/babel_1620871417480/work
# backcall @ file:///home/ktietz/src/ci/backcall_1611930011877/work
# ...

# %%
# !pip install tqdm==4.64.0
# Out:
# ...
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
# ...

# %%
# !pip uninstall holoviews bokeh hvplot panel

# %%
# !pip install holoviews==1.14.9 bokeh==2.4.3 hvplot==0.7.3 panel==0.12.6
